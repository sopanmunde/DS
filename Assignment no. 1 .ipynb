# %% [markdown]
# # Exploratory Data Analysis (EDA) Assignment

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ## Part 1: Data Understanding

# %% [markdown]
# ### Load the dataset and display the first few rows.

# %%
df=pd.read_csv('netflix_titles.csv')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.head(6)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
# 5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...            NaN
#
#            date_added  release_year rating   duration  \
# ...

# %%
df.tail(6)
# Out:
#      show_id     type        title         director  \
# 8801   s8802    Movie      Zinzana  Majid Al Ansari
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast  \
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803                                                NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                            country         date_added  release_year rating  \
# 8801  United Arab Emirates, Jordan      March 9, 2016          2015  TV-MA
# ...

# %% [markdown]
# ### 2. Check the number of rows and columns.

# %%
df.shape
# Out:
# (8807, 12)

# %%
rows, columns =df.shape
print('Rows:', rows)
print('Columns:', columns)
# Out:
# Rows: 8807
# Columns: 12

# %% [markdown]
# ### 3. Identify the types of variables (categorical, numerical, datetime, etc.).

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# ### 4. Check for missing values.

# %%
df.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(4307)

# %% [markdown]
# ### 5. Summarize the dataset using descriptive statistics (mean, median, mode, standard deviation, etc.).

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
outliers = (df[df['release_year'].abs() > 0]).count()
outliers
# Out:
# show_id         8807
# type            8807
# title           8807
# director        6173
# cast            7982
# country         7976
# date_added      8797
# release_year    8807
# rating          8803
# duration        8804
# listed_in       8807
# description     8807
# dtype: int64

# %% [markdown]
# ## Part 2: Data Cleaning

# %% [markdown]
# ### Handle missing values (drop, fill, or impute appropriately).

# %%
df.dropna()
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
df.fillna(0)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water                0
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans                0
# 4         s5  TV Show           Kota Factory                0
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb                0
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                     0  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ### Remove duplicates if any.

# %%
df.drop_duplicates()
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %% [markdown]
# ### Convert data types if necessary.

# %%
df['release_year'].astype(float)
# Out:
# 0       2020.0
# 1       2021.0
# 2       2021.0
# 3       2021.0
# 4       2021.0
#          ...
# 8802    2007.0
# 8803    2018.0
# 8804    2009.0
# 8805    2006.0
# 8806    2015.0
# Name: release_year, Length: 8807, dtype: float64

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# df.corr(method='pearson', min_periods=1, numeric_only=False)

# %% [markdown]
# ### Filling missing values Director and Cast with NoDataAvailable.

# %%
df[['director', 'cast']]=df[['director', 'cast']].fillna('NoDataAvailab')

# %%
df[['director', 'cast']]
# Out:
#              director                                               cast
# 0     Kirsten Johnson                                      NoDataAvailab
# 1       NoDataAvailab  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Julien Leclercq  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3       NoDataAvailab                                      NoDataAvailab
# 4       NoDataAvailab  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# ...               ...                                                ...
# 8802    David Fincher  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803    NoDataAvailab                                      NoDataAvailab
# 8804  Ruben Fleischer  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805     Peter Hewitt  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806      Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
# [8807 rows x 2 columns]

# %% [markdown]
# ### Filling missing values 'country' and 'date added' with mode()’

# %%
df['country'].fillna(df['country'].mode()[0], inplace=True)
df['date_added'].fillna(df['date_added'].mode()[0], inplace=True)
df
# Out:
# C:\Users\SOPAN\AppData\Local\Temp\ipykernel_27228\1973484335.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['country'].fillna(df['country'].mode()[0], inplace=True)
# C:\Users\SOPAN\AppData\Local\Temp\ipykernel_27228\1973484335.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# ### In which year the highest number of the TV Shows and Movies were released? Show with bar graph.

# %%
# Number of TV Shows and Movies released each year
release_counts = df['release_year'].value_counts().sort_index()

plt.figure(figsize=(12,6))
plt.bar(release_counts.index, release_counts.values, color='green')
plt.xlabel('Release Year')
plt.ylabel('Number of Releases')
plt.title('Number of TV Shows and Movies Released Per Year')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

max_year = release_counts.idxmax()
max_count = release_counts.max()
plt.axvline(max_year, color='red', linestyle='--', label=f'Peak Year: {max_year} ({max_count} releases)')
plt.legend()
plt.show()
max_year, max_count
# Out:
# (np.int64(2018), np.int64(1147))

# %% [markdown]
# ### checking the missing 'duration' values. Here few values are missing so we drop that record.

# %%
df_cleaned = df.dropna(subset=['duration'])

missing_duration_count = df_cleaned['duration'].isna().sum()
df_cleaned.shape, missing_duration_count
df_cleaned
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water    NoDataAvailab
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans    NoDataAvailab
# 4         s5  TV Show           Kota Factory    NoDataAvailab
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb    NoDataAvailab
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                         NoDataAvailab  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ### For House of Cards'.What is the show Id and Who is the Director of this show?

# %%
house_of_cards_info = df_cleaned[df_cleaned['title'] == 'House of Cards'][['show_id', 'director']]

house_of_cards_info
# Out:
#      show_id       director
# 1059   s1060  NoDataAvailab

# %% [markdown]
# ### For House of Cards'.What is the show Id and Who is the Director of this show?

# %%
movies_2000 = df_cleaned[(df_cleaned['release_year'] == 2000) & (df_cleaned['type'] == 'Movie')]

movies_2000[['show_id', 'title', 'director', 'country', 'date_added','duration']]
# Out:
#      show_id                                              title  \
# 180     s181                 The Nutty Professor II: The Klumps
# 350     s351                                      Space Cowboys
# 359     s360                       The Original Kings of Comedy
# 566     s567                                   Charlie's Angels
# 593     s594                                           Snow Day
# 779     s780                                  Battlefield Earth
# 952     s953                               The Whole Nine Yards
# 3472   s3473                        Rugrats in Paris: The Movie
# 4545   s4546             Monty Python: Before the Flying Circus
# 4723   s4724                                               Fiza
# 4956   s4957                        Phir Bhi Dil Hai Hindustani
# 5953   s5954                             Joseph: King of Dreams
# 6006   s6007                                            28 Days
# 6147   s6148                                    American Psycho
# ...

# %% [markdown]
# ###  Show Top 10 Directors,who give the highest no of TV Shows and Movies on Netflix?

# %%
# Count the number of shows/movies by each director and get the top 10
directors = df_cleaned['director'].value_counts().head(10)

# Create the bar plot using seaborn
plt.figure(figsize=(12, 6))
sns.barplot(x=directors.index, y=directors.values, palette="Reds_r")

# Customize the plot
plt.xlabel('Director')
plt.ylabel('Number of Movies & TV Shows')
plt.title('Top 10 Directors with the Most Content on Netflix')
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.show()
# Out:
# C:\Users\SOPAN\AppData\Local\Temp\ipykernel_27228\3450286335.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=directors.index, y=directors.values, palette="Reds_r")

# %% [markdown]
# # What is the error in the above bar Graph?
# # If possible, share the code or a description of the issue, and I can help debug it.

# %% [markdown]
# ### Show only the Titles of all TV shows that were released in India only?

# %%
# Filter TV Shows released only in India
tv_shows_india = df_cleaned[(df_cleaned['type'] == 'TV Show') & (df_cleaned['country'] == 'India')]

tv_shows_india[['title']]
# Out:
#                                    title
# 4                           Kota Factory
# 39                          Chhota Bheem
# 50                         Dharmakshetra
# 66         Raja Rasoi Aur Anya Kahaniyan
# 69        Stories by Rabindranath Tagore
# ...                                  ...
# 8173                           Thackeray
# 8235                         The Calling
# 8321  The Golden Years with Javed Akhtar
# 8349              The House That Made Me
# 8775                     Yeh Meri Family
#
# [79 rows x 1 columns]

# %% [markdown]
# # Part 3: Data Visualisation

# %%
# Filter dataset for titles containing Damsel
damsel_counts = df_cleaned[df_cleaned['title'].str.contains("Damsel", case=False, na=False)]['type'].value_counts()

plt.figure(figsize=(6, 4))
sns.barplot(x=damsel_counts.index, y=damsel_counts.values, palette="Blues_r")

plt.xlabel('Type')
plt.ylabel('Count')
plt.title('Number of Movies and TV Shows with Title "Damsel"')
plt.xticks(rotation=0)
plt.show()

damsel_counts
# Out:
# Series([], Name: count, dtype: int64)

# %%
# Count the number of TV Shows and Movies by each country
country_counts = df_cleaned['country'].value_counts().head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=country_counts.index, y=country_counts.values, palette="viridis")

plt.xlabel('Country')
plt.ylabel('Number of TV Shows & Movies')
plt.title('Top 10 Countries with the Highest Number of TV Shows & Movies on Netflix')
plt.xticks(rotation=45, ha='right')

plt.show()            # Show the plot

country_counts      # Display the top 10 countries with counts
# Out:
# C:\Users\SOPAN\AppData\Local\Temp\ipykernel_27228\3192870473.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=country_counts.index, y=country_counts.values, palette="viridis")
# country
# United States     3646
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: count, dtype: int64

# %% [markdown]
# ### Which genres are most common on Netflix?

# %%
# Count the number of TV Shows added each year
tv_shows_by_year = df_cleaned[df_cleaned['type'] == 'TV Show']['release_year'].value_counts().sort_index()

plt.figure(figsize=(12, 6))
sns.lineplot(x=tv_shows_by_year.index, y=tv_shows_by_year.values, marker='o', color='blue')

plt.xlabel('Year')
plt.ylabel('Number of TV Shows Added')
plt.title('Number of TV Shows Added Over the Years')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

df.shape
# Out:
# (8807, 12)

# %% [markdown]
# ### Top 10 countries with the highest number of movies.

# %%
# Count the number of Movies by each country
movie_counts_by_country = df_cleaned[df_cleaned['type'] == 'Movie']['country'].value_counts().head(10)

plt.figure(figsize=(12, 6))
sns.barplot(x=movie_counts_by_country.index, y=movie_counts_by_country.values, palette="magma")

plt.xlabel('Country')
plt.ylabel('Number of Movies')
plt.title('Top 10 Countries with the Highest Number of Movies on Netflix')
plt.xticks(rotation=45, ha='right')

plt.show()

movie_counts_by_country
# Out:
# C:\Users\SOPAN\AppData\Local\Temp\ipykernel_27228\3670941474.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=movie_counts_by_country.index, y=movie_counts_by_country.values, palette="magma")
# country
# United States     2495
# India              893
# United Kingdom     206
# Canada             122
# Spain               97
# Egypt               92
# Nigeria             86
# Indonesia           77
# Japan               76
# Turkey              76
# Name: count, dtype: int64

# %% [markdown]
# ### Growth of Netflix Content in Different Countries – Use a line graph to compare how many movies/TV shows have been added over the years for different countries.

# %%
# Select top 5 countries with the most content
top_countries = df_cleaned['country'].value_counts().head(5).index


country_year_data = df_cleaned[df_cleaned['country'].isin(top_countries)]       # Filter data for selected countries

country_trend = country_year_data.groupby(['release_year', 'country']).size().unstack()    # Count the number of Movies & TV Shows added over the years for each country

plt.figure(figsize=(12, 6))            # Plot the line graph using Seaborn
sns.lineplot(data=country_trend, marker='o')

plt.xlabel('Year')
plt.ylabel('Number of Movies & TV Shows')
plt.title('Growth of Netflix Content in Different Countries Over the Years')
plt.legend(title="Country", loc="upper left")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # Part 4: Insights and Summary

# %% [markdown]
# ### 1. What trends or patterns do you observe?

# %% [raw]
# Ans:- Netflix Content Growth (2018-2020 Peak)
#
# -There was a huge content addition during 2018-2020, which depicts Netflix's bold growth strategy.
# Domination of US & India
#
# -The United States boasts the maximum number of TV shows and movies.
# India closely follows it with immense growth in Bollywood and local content.
# TV Shows in Growth
#
# -Netflix was initially film-oriented, but since 2016, TV shows have been given priority to enhance viewership engagement.
# Global Expansion in Content
#
# -Rajiv Chilaka (Indian Animation) and Raúl Campos, Jan Suter (Mexican Content) are some of the leading directors.
# Hollywood legends such as Martin Scorsese and Steven Spielberg also possess multiple works.
# Recent Content Accounts for Most of Netflix
#
# -Most of the content is from 2010 onwards, reflecting the move towards contemporary entertainment trends.
# Older films (pre-2000s) are not common, since Netflix favors newer releases.
# Missing Data Challenges
#
# -There are some records missing director, country, or duration information, which may indicate metadata tagging inconsistencies.

# %% [markdown]
# ### 2. Are there any correlations between features?

# %% [raw]
# Ans:  No, there are no high correlations between attributes in the Netflix dataset.
#
# Why?
# -Most attributes are categorical (e.g., title, director, country, genre, type), not numerical.
# -The dataset does not contain continuous numerical values, so it is difficult to identify significant correlations.
# -No direct dependency exists between attributes such as director, country, and type.
# -Only 'release_year' and 'duration' are numerical, but they do not have a strong relationship.
# -Would you like me to investigate other patterns in the data?

# %% [markdown]
# ### 3. What are your key takeaways from the dataset?

# %% [raw]
# Ans: -Netflix expanded from 2018-2020, adding the most content.
# -The US and India have the most movies and TV shows.
# -TV shows became more popular after 2016, overtaking movies as Netflix's priority.
# -Netflix spread worldwide, adding more Spanish, Korean, and Mexican content.
# -Most content is new (after 2010), with very few old films (pre-2000).
# -Top directors are Rajiv Chilaka (Indian animation) and Raúl Campos (Mexican content).
# -Strong feature correlations are not present because of categorical data.
# -Missing information in some records (director, country, or duration).
